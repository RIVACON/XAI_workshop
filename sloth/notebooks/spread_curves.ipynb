# %%
import sys
sys.path.append('..')
sys.path.append('../../shapley/')
import models.spread_curves as spread_curves
from sloth.ice import ICE
from sloth.shap import Shap, Method
#from models.spread_curves import get_validation_task
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
validation_task = spread_curves.get_validation_task()

# %%
ice = ICE(validation_task)
ice.plot(n_plots=(1,2))

# %%
depp = Shap(validation_task, max_background_data=1000, max_single_values=100, method=Method.SHAP_EXACT)
plt.savefig('shap_spreads.png', dpi=400)

# %%
depp.plot_beeswarm()
plt.savefig('shap_spreads.png', dpi=400)

# %%
x = model.sample_data(n_samples=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 x = model.sample_data(n_samples=1000)
#
# NameError: name 'model' is not defined

# %%
x.shape

# %%
explainer = shap.Explainer(model.predict, x, feature_names=feature_names)
shap_values = explainer(x[:100,:])

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.bar(shap_values)
